# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from pybaseball import batting_stats
import seaborn as sns

# %matplotlib inline

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
batting_df = batting_stats(2025)
batting_df.head()
# Out:
#      IDfg  Season             Name Team  Age    G   AB   PA    H   1B  2B  3B  \
# 0   15640    2025      Aaron Judge  NYY   33  152  541  679  179   94  30   2
# 3   21534    2025      Cal Raleigh  SEA   28  159  596  705  147   63  24   0
# 22  25764    2025   Bobby Witt Jr.  KCR   25  157  623  687  184  108  47   6
# 1   19755    2025    Shohei Ohtani  LAD   30  158  611  727  172   83  25   9
# 8   22799    2025  Geraldo Perdomo  ARI   25  161  597  720  173  115  33   5
#
#     HR    R  RBI   BB  IBB   SO  HBP  SF  SH  GDP  SB  CS    AVG   GB   FB  \
# 0   53  137  114  124   36  160    7   7   0   16  12   5  0.331  132  180
# 3   60  110  125   97   17  188    9   3   0    6  14   4  0.247  103  237
# 22  23   99   88   49    8  125    8   7   0    7  38   9  0.295  187  216
# 1   55  146  102  109   20  187    3   2   0    9  20   6  0.282  167  187
# 8   20   98  100   94    1   83   10  11   8   11  27   6  0.290  193  202
#
#      LD  IFFB  Pitches  Balls  Strikes  IFH  BU  BUH    BB%     K%  BB/K  \
# 0    76    12     2634   1089     1545    6   0    0  0.183  0.236  0.78
# 3    71    33     2833   1068     1765    7   0    0  0.138  0.267  0.52
# 22  102    23     2512    878     1634   17   0    0  0.071  0.182  0.39
# 1    72    10     2868   1154     1714   15   0    0  0.150  0.257  0.58
# 8   120    28     3007   1170     1837   12  18    5  0.131  0.115  1.13
#
#       OBP    SLG    OPS    ISO  BABIP   GB/FB    LD%    GB%    FB%  IFFB%  \
# 0   0.457  0.688  1.144  0.357  0.376  0.0073  0.196  0.340  0.464  0.067
# 3   0.359  0.589  0.948  0.342  0.248  0.0043  0.173  0.251  0.577  0.139
# 22  0.351  0.501  0.852  0.205  0.334  0.0087  0.202  0.370  0.428  0.106
# 1   0.392  0.622  1.014  0.340  0.315  0.0089  0.169  0.392  0.439  0.053
# 8   0.389  0.462  0.851  0.173  0.303  0.0096  0.233  0.375  0.392  0.139
#
#     HR/FB   IFH%   BUH%   wOBA  wRAA  wRC   Bat   Fld   Rep   Pos   RAR   WAR  \
# 0   0.294  0.045  0.000  0.463  82.5  163  83.6   6.4  20.7 -10.3  99.0  10.1
# 3   0.253  0.068  0.000  0.392  45.2  128  50.8  11.2  21.5   5.1  88.6   9.1
# 22  0.106  0.091  0.000  0.360  26.3  108  24.1  16.7  20.9   6.5  78.3   8.0
# 1   0.294  0.090  0.000  0.418  61.8  148  62.3   NaN  22.1 -17.1  73.1   7.5
# 8   0.099  0.062  0.278  0.370  33.2  118  32.4   1.7  21.9   7.3  69.2   7.1
#
#       Dol  Spd  wRC+   WPA   -WPA   +WPA   RE24   REW   pLI  phLI  PH  WPA/LI  \
# 0   $81.0  4.6   204  5.61  -8.63  14.24  73.78  7.67  0.90  2.81   1    7.71
# 3   $72.5  3.6   161  3.84 -11.43  15.27  52.96  5.81  1.03  4.81   2    4.64
# 22  $64.1  6.9   130  3.37 -11.21  14.58  34.78  3.57  1.00   NaN   0    3.46
# 1   $59.8  7.1   172  5.89 -10.53  16.41  56.96  5.82  0.96   NaN   0    5.89
# 8   $56.6  5.7   138  3.45 -10.96  14.41  40.90  4.22  0.98  4.08   1    3.05
#
#     Clutch  FB% (Pitch)   FBv    SL%   SLv    CT%   CTv    CB%   CBv    CH%  \
# 0    -1.50        0.401  94.9  0.280  85.6  0.090  89.3  0.078  80.8  0.109
# 3    -0.91        0.422  94.3  0.189  85.4  0.078  89.9  0.100  80.4  0.163
# 22   -0.08        0.468  94.4  0.244  85.8  0.108  89.0  0.068  80.2  0.083
# 1     0.25        0.441  94.6  0.216  85.1  0.071  90.2  0.103  81.8  0.126
# 8     0.47        0.534  94.4  0.159  85.4  0.066  89.4  0.107  80.6  0.097
#
#      CHv    SF%   SFv  KN%  KNv    XX%  PO%   wFB  wSL   wCT   wCB  wCH  wSF  \
# 0   85.9  0.042  87.0  NaN  NaN  0.050  NaN  41.2  9.5  16.6  -0.1  8.9 -2.8
# 3   85.8  0.048  86.3  NaN  NaN  0.022  NaN  23.3  2.6   0.8   5.0  6.5  4.3
# 22  85.3  0.029  86.4  NaN  NaN  0.012  NaN   4.6  2.4   5.0  10.3  4.7  1.9
# 1   87.1  0.044  87.5  NaN  NaN  0.026  NaN  20.9  8.6   8.1   9.9  8.7  3.0
# 8   86.0  0.037  86.5  NaN  NaN  0.001  NaN  17.0  9.1   4.9   5.7  0.8  1.6
#
#     wKN  wFB/C  wSL/C  wCT/C  wCB/C  wCH/C  wSF/C  wKN/C  O-Swing%  Z-Swing%  \
# 0   NaN   3.91   1.28   6.99  -0.07   3.09  -2.58    NaN     0.257     0.703
# 3   NaN   1.95   0.48   0.35   1.78   1.41   3.16    NaN     0.357     0.769
# 22  NaN   0.39   0.39   1.84   6.00   2.23   2.61    NaN     0.345     0.737
# 1   NaN   1.65   1.38   4.00   3.37   2.41   2.39    NaN     0.296     0.675
# 8   NaN   1.06   1.90   2.49   1.77   0.27   1.40    NaN     0.219     0.587
#
#     Swing%  O-Contact%  Z-Contact%  Contact%  Zone%  F-Strike%  SwStr%  BsR  \
# 0    0.437       0.444       0.802     0.676  0.402      0.554   0.141 -4.1
# 3    0.517       0.558       0.827     0.713  0.389      0.603   0.148 -2.8
# 22   0.511       0.650       0.868     0.783  0.423      0.622   0.111  7.4
# 1    0.449       0.522       0.788     0.684  0.405      0.582   0.142  3.7
# 8    0.392       0.802       0.937     0.897  0.471      0.586   0.040  3.8
#
#     FA% (sc)  FT% (sc)  FC% (sc)  FS% (sc)  FO% (sc)  SI% (sc)  SL% (sc)  \
# 0      0.259       NaN     0.086     0.041       NaN     0.137     0.287
# 3      0.340       NaN     0.079     0.048       NaN     0.078     0.182
# 22     0.336       NaN     0.114     0.027     0.001     0.125     0.243
# 1      0.301       NaN     0.074     0.038     0.001     0.138     0.205
# 8      0.411       NaN     0.063     0.036     0.002     0.120     0.165
#
#     CU% (sc)  KC% (sc)  EP% (sc)  CH% (sc)  SC% (sc)  KN% (sc)  UN% (sc)  \
# 0      0.063     0.017     0.000     0.111       NaN       NaN       NaN
# 3      0.093     0.015     0.001     0.163       NaN       NaN       NaN
# 22     0.051     0.018     0.002     0.086       NaN       NaN       NaN
# 1      0.089     0.025       NaN     0.129       NaN       NaN       NaN
# 8      0.092     0.015     0.000     0.096       NaN       NaN       NaN
#
#     vFA (sc)  vFT (sc)  vFC (sc)  vFS (sc)  vFO (sc)  vSI (sc)  vSL (sc)  \
# 0       95.1       NaN      89.9      87.1       NaN      94.5      85.6
# 3       94.6       NaN      90.1      86.2       NaN      93.8      85.5
# 22      94.7       NaN      89.4      86.7      82.9      93.8      85.7
# 1       94.9       NaN      90.4      87.4      82.9      93.8      85.1
# 8       94.6       NaN      89.9      86.5      82.2      93.9      85.5
#
#     vCU (sc)  vKC (sc)  vEP (sc)  vCH (sc)  vSC (sc)  vKN (sc)  FA-X (sc)  \
# 0       80.3      81.3      55.3      85.9       NaN       NaN       -2.2
# 3       79.9      84.2      39.6      85.8       NaN       NaN       -2.3
# 22      79.2      82.8      51.5      85.3       NaN       NaN       -2.4
# 1       81.2      83.2       NaN      87.2       NaN       NaN       -2.2
# 8       80.0      82.4      48.3      86.1       NaN       NaN       -2.0
#
#     FT-X (sc)  FC-X (sc)  FS-X (sc)  FO-X (sc)  SI-X (sc)  SL-X (sc)  \
# 0         NaN        0.6       -5.8        NaN       -6.9        3.0
# 3         NaN        0.3       -5.8        NaN       -2.9        1.4
# 22        NaN        0.6       -6.2       -6.1       -5.4        2.9
# 1         NaN        0.1       -5.7       -6.2        0.7        0.2
# 8         NaN        0.2       -4.9       -5.4       -2.3        1.6
#
#     CU-X (sc)  KC-X (sc)  EP-X (sc)  CH-X (sc)  SC-X (sc)  KN-X (sc)  \
# 0         2.4        3.4       -2.9       -1.7        NaN        NaN
# 3         0.8        3.0       -1.7       -3.1        NaN        NaN
# 22        1.8        2.8       -1.6        0.3        NaN        NaN
# 1         2.7        2.5        NaN       -5.7        NaN        NaN
# 8         2.9        1.6       -3.2       -2.6        NaN        NaN
#
#     FA-Z (sc)  FT-Z (sc)  FC-Z (sc)  FS-Z (sc)  FO-Z (sc)  SI-Z (sc)  \
# 0         9.3        NaN        4.3        2.3        NaN        4.6
# 3         9.3        NaN        4.7        2.7        NaN        4.0
# 22        9.3        NaN        4.4        2.6        0.6        5.0
# 1         9.0        NaN        4.9        2.4        1.2        4.0
# 8         9.1        NaN        4.9        2.6        1.1        4.5
#
#     SL-Z (sc)  CU-Z (sc)  KC-Z (sc)  EP-Z (sc)  CH-Z (sc)  SC-Z (sc)  \
# 0         0.9       -5.1       -6.3       -2.6        2.8        NaN
# 3         1.2       -5.8       -5.0        3.8        2.9        NaN
# 22        1.2       -5.8       -4.0        9.7        2.9        NaN
# 1         0.8       -4.8       -4.2        NaN        2.8        NaN
# 8         1.1       -5.7       -3.9        5.6        2.9        NaN
#
#     KN-Z (sc)  wFA (sc)  wFT (sc)  wFC (sc)  wFS (sc)  wFO (sc)  wSI (sc)  \
# 0         NaN      20.6       NaN      14.6      -2.8       NaN      20.3
# 3         NaN      10.5       NaN       0.6       4.0       NaN      13.2
# 22        NaN       4.6       NaN       4.4       1.6      -0.1      -2.5
# 1         NaN      10.2       NaN       6.2       3.3      -0.2       7.2
# 8         NaN       7.2       NaN       3.0       0.9      -0.4       5.7
#
#     wSL (sc)  wCU (sc)  wKC (sc)  wEP (sc)  wCH (sc)  wSC (sc)  wKN (sc)  \
# 0       11.1      -0.3      -0.5      -0.3       9.0       NaN       NaN
# 3        2.3       4.0       0.7       0.0       6.2       NaN       NaN
# 22       4.9       5.7       2.9       0.1       5.0       NaN       NaN
# 1       12.7       5.6       3.4       NaN       8.4       NaN       NaN
# 8       10.5       2.6       1.7       0.8       1.9       NaN       NaN
#
#     wFA/C (sc)  wFT/C (sc)  wFC/C (sc)  wFS/C (sc)  wFO/C (sc)  wSI/C (sc)  \
# 0         3.02         NaN        6.50       -2.59         NaN        5.63
# 3         1.09         NaN        0.25        2.93         NaN        5.96
# 22        0.54         NaN        1.53        2.34       -6.41       -0.79
# 1         1.19         NaN        2.92        3.03       -4.61        1.83
# 8         0.58         NaN        1.57        0.88       -6.19        1.57
#
#     wSL/C (sc)  wCU/C (sc)  wKC/C (sc)  wEP/C (sc)  wCH/C (sc)  wSC/C (sc)  \
# 0         1.47       -0.16       -1.11      -30.20        3.09         NaN
# 3         0.45        1.51        1.56       -1.02        1.33         NaN
# 22        0.80        4.52        6.55        3.25        2.32         NaN
# 1         2.16        2.21        4.85         NaN        2.28         NaN
# 8         2.13        0.94        3.78       77.08        0.64         NaN
#
#     wKN/C (sc)  O-Swing% (sc)  Z-Swing% (sc)  Swing% (sc)  O-Contact% (sc)  \
# 0          NaN          0.223          0.659        0.437            0.334
# 3          NaN          0.319          0.735        0.517            0.505
# 22         NaN          0.310          0.698        0.511            0.601
# 1          NaN          0.262          0.643        0.450            0.441
# 8          NaN          0.193          0.551        0.392            0.748
#
#     Z-Contact% (sc)  Contact% (sc)  Zone% (sc)  Pace   Def  wSB  UBR  Age Rng  \
# 0             0.796          0.676       0.490  19.0  -3.8 -0.9  NaN  33 - 33
# 3             0.813          0.713       0.476  19.6  16.3  0.2  NaN  28 - 28
# 22            0.858          0.783       0.518  19.0  23.2  2.9  NaN  25 - 25
# 1             0.786          0.684       0.494  18.2 -17.1  0.4  NaN  30 - 30
# 8             0.936          0.895       0.555  18.0   9.0  1.5  NaN  25 - 25
#
#      Off   Lg  wGDP  Pull%  Cent%  Oppo%  Soft%   Med%  Hard%   TTO%  \
# 0   79.5  2.7   NaN  0.366  0.374  0.260  0.098  0.446  0.456  0.496
# 3   48.0  2.8   NaN  0.555  0.251  0.195  0.190  0.428  0.382  0.489
# 22  31.5  2.7   NaN  0.349  0.368  0.283  0.143  0.453  0.404  0.287
# 1   66.0  2.1   NaN  0.455  0.371  0.174  0.099  0.448  0.453  0.483
# 8   36.2  2.0   NaN  0.432  0.315  0.253  0.159  0.559  0.281  0.274
#
#     CH% (pi)  CS% (pi)  CU% (pi)  FA% (pi)  FC% (pi)  FS% (pi)  KN% (pi)  \
# 0      0.111       NaN     0.071     0.260     0.082     0.038       NaN
# 3      0.167       0.0     0.096     0.342     0.078     0.043       NaN
# 22     0.086       NaN     0.061     0.333     0.100     0.024       NaN
# 1      0.135       NaN     0.101     0.294     0.079     0.034       NaN
# 8      0.103       NaN     0.103     0.405     0.073     0.029       NaN
#
#     SB% (pi)  SI% (pi)  SL% (pi)  XX% (pi)  vCH (pi)  vCS (pi)  vCU (pi)  \
# 0        NaN     0.138     0.300       NaN      85.8       NaN      80.2
# 3        NaN     0.076     0.197       NaN      85.8      64.7      80.5
# 22       NaN     0.132     0.263       NaN      85.2       NaN      79.8
# 1        NaN     0.141     0.216       NaN      86.9       NaN      81.7
# 8        NaN     0.121     0.165       NaN      85.9       NaN      80.2
#
#     vFA (pi)  vFC (pi)  vFS (pi)  vKN (pi)  vSB (pi)  vSI (pi)  vSL (pi)  \
# 0       95.0      89.7      87.0       NaN       NaN      94.5      85.5
# 3       94.4      90.6      86.1       NaN       NaN      93.8      85.3
# 22      94.8      89.8      85.9       NaN       NaN      94.1      85.9
# 1       95.1      90.6      86.5       NaN       NaN      93.8      84.8
# 8       94.6      90.3      85.9       NaN       NaN      93.9      85.3
#
#     vXX (pi)  CH-X (pi)  CS-X (pi)  CU-X (pi)  FA-X (pi)  FC-X (pi)  \
# 0        NaN       -1.6        NaN        2.9       -2.0        1.0
# 3        NaN       -3.1       -1.6        1.8       -2.0        0.6
# 22       NaN        0.4        NaN        2.0       -2.0        0.9
# 1        NaN       -5.5        NaN        3.7       -2.0        0.5
# 8        NaN       -2.7        NaN        3.0       -1.9        0.4
#
#     FS-X (pi)  KN-X (pi)  SB-X (pi)  SI-X (pi)  SL-X (pi)  XX-X (pi)  \
# 0        -5.8        NaN        NaN       -6.6        3.4        NaN
# 3        -4.8        NaN        NaN       -2.8        1.4        NaN
# 22       -5.6        NaN        NaN       -5.4        3.6        NaN
# 1        -4.8        NaN        NaN        0.5        0.0        NaN
# 8        -4.6        NaN        NaN       -2.3        1.9        NaN
#
#     CH-Z (pi)  CS-Z (pi)  CU-Z (pi)  FA-Z (pi)  FC-Z (pi)  FS-Z (pi)  \
# 0         1.4        NaN       -7.4        8.4        3.4        0.6
# 3         1.5       -2.7       -7.8        8.3        4.1        1.2
# 22        1.6        NaN       -7.5        8.3        3.6        0.9
# 1         1.5        NaN       -6.7        8.1        4.2        1.2
# 8         1.5        NaN       -7.2        8.1        4.1        0.8
#
#     KN-Z (pi)  SB-Z (pi)  SI-Z (pi)  SL-Z (pi)  XX-Z (pi)  wCH (pi)  wCS (pi)  \
# 0         NaN        NaN        3.4       -0.5        NaN       8.7       NaN
# 3         NaN        NaN        2.7       -0.4        NaN       5.8       0.0
# 22        NaN        NaN        3.9       -0.1        NaN       4.8       NaN
# 1         NaN        NaN        2.7       -0.7        NaN       8.8       NaN
# 8         NaN        NaN        3.2       -0.3        NaN      -0.5       NaN
#
#     wCU (pi)  wFA (pi)  wFC (pi)  wFS (pi)  wKN (pi)  wSB (pi)  wSI (pi)  \
# 0       -1.2      19.3      16.7      -2.7       NaN       NaN      19.3
# 3        5.7      11.0      -1.3       4.6       NaN       NaN      13.5
# 22       7.3       5.4       1.3       1.5       NaN       NaN      -2.6
# 1       10.0       9.7       6.4       1.9       NaN       NaN       9.3
# 8        4.8       9.2       3.0       3.0       NaN       NaN       5.3
#
#     wSL (pi)  wXX (pi)  wCH/C (pi)  wCS/C (pi)  wCU/C (pi)  wFA/C (pi)  \
# 0       11.9       NaN        2.97         NaN       -0.65        2.83
# 3        2.3       NaN        1.21        3.51        2.09        1.13
# 22       9.1       NaN        2.22         NaN        4.74        0.65
# 1       10.6       NaN        2.29         NaN        3.44        1.15
# 8        9.1       NaN       -0.17         NaN        1.56        0.76
#
#     wFC/C (pi)  wFS/C (pi)  wKN/C (pi)  wSB/C (pi)  wSI/C (pi)  wSL/C (pi)  \
# 0         7.76       -2.63         NaN         NaN        5.32        1.51
# 3        -0.59        3.80         NaN         NaN        6.26        0.42
# 22        0.51        2.40         NaN         NaN       -0.77        1.39
# 1         2.82        1.92         NaN         NaN        2.31        1.71
# 8         1.38        3.40         NaN         NaN        1.45        1.83
#
#     wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  Swing% (pi)  O-Contact% (pi)  \
# 0          NaN          0.225          0.659        0.437            0.356
# 3          NaN          0.319          0.735        0.517            0.503
# 22         NaN          0.308          0.694        0.511            0.602
# 1          NaN          0.262          0.643        0.450            0.430
# 8          NaN          0.195          0.549        0.391            0.748
#
#     Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  Pace (pi)   FRM  AVG+  BB%+  \
# 0             0.788          0.674       0.488       19.0   NaN   136   221
# 3             0.814          0.713       0.477       19.6  11.1   101   166
# 22            0.855          0.783       0.526       19.0   NaN   121    86
# 1             0.790          0.684       0.493       18.2   NaN   114   176
# 8             0.938          0.895       0.554       18.0   NaN   117   153
#
#     K%+  OBP+  SLG+  ISO+  BABIP+  LD+%  GB%+  FB%+  HR/FB%+  Pull%+  Cent%+  \
# 0   105   146   170   220     130  1.00    83   118      242      89     108
# 3   118   115   145   211      86  0.89    61   147      208     134      72
# 22   81   112   123   127     116  1.04    90   109       87      84     106
# 1   117   123   155   219     108  0.85    93   116      255     112     106
# 8    53   123   115   111     103  1.17    89   104       86     106      90
#
#     Oppo%+  Soft%+  Med%+  Hard%+    EV    LA  Barrels  Barrel%  maxEV  \
# 0      108      62     86     141  95.4  19.1       96    0.247  118.1
# 3       81     120     83     118  91.3  25.2       80    0.195  114.7
# 22     118      90     88     125  93.3  15.2       63    0.125  117.5
# 1       72      63     86     140  94.9  15.0      100    0.234  120.0
# 8      105     102    107      87  87.6  15.5       33    0.062  108.2
#
#     HardHit  HardHit%  Events  CStr%   CSW%    xBA   xSLG  xwOBA  L-WAR
# 0       226     0.582     388  0.150  0.292  0.315  0.735  0.475   10.2
# 3       204     0.496     411  0.106  0.254  0.244  0.568  0.384    9.2
# 22      245     0.485     505  0.140  0.250  0.299  0.521  0.377    7.5
# 1       250     0.584     428  0.147  0.289  0.288  0.672  0.439    7.2
# 8       170     0.319     533  0.214  0.254  0.285  0.432  0.361    6.9

# %%
stats = batting_df[['Name', 'PA', 'AVG', 'OBP', 'OPS', 'HR', 'RBI', 'K%', 'Hard%', 'SB']]
stats.head()
# Out:
#                Name   PA    AVG    OBP    OPS  HR  RBI     K%  Hard%  SB
# 0       Aaron Judge  679  0.331  0.457  1.144  53  114  0.236  0.456  12
# 3       Cal Raleigh  705  0.247  0.359  0.948  60  125  0.267  0.382  14
# 22   Bobby Witt Jr.  687  0.295  0.351  0.852  23   88  0.182  0.404  38
# 1     Shohei Ohtani  727  0.282  0.392  1.014  55  102  0.257  0.453  20
# 8   Geraldo Perdomo  720  0.290  0.389  0.851  20  100  0.115  0.281  27

# %%
sb_percentage = batting_df['SB'] / (batting_df['SB'] + batting_df['CS'])
stats['SB%'] = sb_percentage
stats = stats.sort_index()
stats.head()
# Out:
# /var/folders/y2/ffmphcn51c18jj38jsf88tyc0000gn/T/ipykernel_99546/788467766.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stats['SB%'] = sb_percentage
#               Name   PA    AVG    OBP    OPS  HR  RBI     K%  Hard%  SB  \
# 0      Aaron Judge  679  0.331  0.457  1.144  53  114  0.236  0.456  12
# 1    Shohei Ohtani  727  0.282  0.392  1.014  55  102  0.257  0.453  20
# 2  George Springer  586  0.309  0.399  0.959  32   84  0.189  0.353  18
# 3      Cal Raleigh  705  0.247  0.359  0.948  60  125  0.267  0.382  14
# 4   Kyle Schwarber  724  0.240  0.365  0.928  56  132  0.272  0.453  10
#
#         SB%
# 0  0.705882
# 1  0.769231
# 2  0.947368
# 3  0.777778
# 4  0.833333

# %%
names = stats['Name']
no_name_pa_df = stats.drop(['Name', 'PA'], axis=1)
no_name_pa_df.head()
# Out:
#      AVG    OBP    OPS  HR  RBI     K%  Hard%  SB       SB%
# 0  0.331  0.457  1.144  53  114  0.236  0.456  12  0.705882
# 1  0.282  0.392  1.014  55  102  0.257  0.453  20  0.769231
# 2  0.309  0.399  0.959  32   84  0.189  0.353  18  0.947368
# 3  0.247  0.359  0.948  60  125  0.267  0.382  14  0.777778
# 4  0.240  0.365  0.928  56  132  0.272  0.453  10  0.833333

# %%
scaler = MinMaxScaler()
norm_array = scaler.fit_transform(no_name_pa_df)
norm_df = pd.DataFrame(norm_array,columns=no_name_pa_df.columns)
norm_df.insert(0, 'Name', names)
norm_df = norm_df.fillna(0)
norm_df.head()
# Out:
#               Name       AVG       OBP       OPS        HR       RBI  \
# 0      Aaron Judge  1.000000  1.000000  1.000000  0.877193  0.834862
# 1    Shohei Ohtani  0.625954  0.656085  0.764065  0.912281  0.724771
# 2  George Springer  0.832061  0.693122  0.664247  0.508772  0.559633
# 3      Cal Raleigh  0.358779  0.481481  0.644283  1.000000  0.935780
# 4   Kyle Schwarber  0.305344  0.513228  0.607985  0.929825  1.000000
#
#          K%     Hard%        SB       SB%
# 0  0.702055  1.000000  0.272727  0.705882
# 1  0.773973  0.989130  0.454545  0.769231
# 2  0.541096  0.626812  0.409091  0.947368
# 3  0.808219  0.731884  0.318182  0.777778
# 4  0.825342  0.989130  0.227273  0.833333

# %%
hr_rating = 0.23 * norm_df['HR']
obp_rating = 0.15 * norm_df['OBP']
ops_rating = 0.14 * norm_df['OPS']
avg_rating = 0.10 * norm_df['AVG']
k_percent_rating = 0.10 * (1 - norm_df['K%'])
rbi_rating = 0.10 * norm_df['RBI']
sb_rating = 0.08 * norm_df['SB']
sb_percent_rating = 0.06 * norm_df['SB%']
hard_percent_rating = 0.04 * norm_df['Hard%']
rating = hr_rating + obp_rating + ops_rating + avg_rating + k_percent_rating + rbi_rating + sb_rating + sb_percent_rating + hard_percent_rating
rating = rating * 100
rating.head()
# Out:
# 0    80.920627
# 1    69.496433
# 2    61.368202
# 3    64.245236
# 4    63.170888
# dtype: float64

# %%
rating_lst = rating.tolist()
tmp_rating_dict = {'Rating': rating_lst}
rating_df = pd.DataFrame(tmp_rating_dict)
rating_df.insert(0, 'Name', names)
rating_df = rating_df.sort_values(by='Rating', ascending=False)
rating_df.head()
# Out:
#              Name     Rating
# 0     Aaron Judge  80.920627
# 1   Shohei Ohtani  69.496433
# 5       Juan Soto  67.629659
# 3     Cal Raleigh  64.245236
# 4  Kyle Schwarber  63.170888

# %%
top_ten_ratings = rating_df.iloc[:9, :]
top_ten_ratings
# Out:
#                Name     Rating
# 0       Aaron Judge  80.920627
# 1     Shohei Ohtani  69.496433
# 5         Juan Soto  67.629659
# 3       Cal Raleigh  64.245236
# 4    Kyle Schwarber  63.170888
# 2   George Springer  61.368202
# 23     Jose Ramirez  59.421086
# 8   Geraldo Perdomo  55.357864
# 22   Bobby Witt Jr.  54.288749

# %%
fig, ax = plt.subplots(figsize=(15,10))
plt.bar(top_ten_ratings['Name'], top_ten_ratings['Rating'])
plt.title('Top Ten Ratings', y=1.02)
plt.xlabel('Players')
plt.ylabel('Ratings')
plt.show()
